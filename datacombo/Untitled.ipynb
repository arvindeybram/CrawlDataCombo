# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv("all.txt",sep=' ',header=None,)

# %%
file.head()
# Out:
#                                                    0
# 0  http://www.lauradayliving.com/favorites/artist...
# 1                            http://www.sparrow.org/
# 2            http://www.lauradayliving.com/home.html
# 3  https://ee.co.uk/help/help-new/billing-usage-a...
# 4                    https://globalchallenges.org/en

# %%
file.columns=['URL']

# %%
len(file)
# Out:
# 979111

# %%
file["URL"]= file["URL"].str.split(".", expand = True)

# %%
file
# Out:
#                                URL
# 0                       http://www
# 1                       http://www
# 2                       http://www
# 3                       https://ee
# 4         https://globalchallenges
# 5                      https://www
# 6                      https://www
# 7               http://nathanfrohm
# 8                      https://www
# 9                      https://www
# 10                     https://www
# 11                     https://www
# 12                     https://www
# 13                      http://www
# 14                      http://www
# 15                      http://www
# 16                     https://www
# 17                      http://www
# 18                      http://www
# 19                      http://www
# 20                      http://www
# 21                      http://www
# 22                     https://www
# 23                      http://www
# 24                      http://www
# 25                      http://www
# ...
